# %%
import gym
import numpy as np
import keras
import random
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D

from baselines import deepq
from baselines.common.atari_wrappers import make_atari


env = make_atari('BreakoutNoFrameskip-v4')
env = deepq.wrap_atari_dqn(env)


# def preprocess(observation):
#     observation = cv2.cvtColor(cv2.resize(observation, (84, 110)), cv2.COLOR_BGR2GRAY)
#     observation = observation[26:110,:]
#     return np.reshape(observation,(84,84,1))

class QNetwork:
    def __init__(self, learning_rate=0.01, state_size=4,
                 action_size=2, hidden_size=10):
        # state inputs to the Q-network
        self.model = Sequential()

        self.model.add(Dense(hidden_size, activation='relu',
                             input_dim=state_size))
        self.model.add(Dense(hidden_size, activation='relu'))
        self.model.add(Dense(action_size, activation='linear'))

        self.optimizer = Adam(lr=learning_rate)
        self.model.compile(loss='mse', optimizer=self.optimizer)
        
        
def visualizeFrames(obs):
    
    for i in range(0, 4):
        elem = obs[:, :, i]
        plt.imshow(np.array(np.squeeze(elem)))
        plt.show()
    print('--------')
        
        

    
for i in range (0, 1000):
    
    done = False
    obs1 = env.reset()
    print('episode ', i)
    while not done:
        obs2, reward, done, info = env.step(env.action_space.sample())
        env.render()
        visualizeFrames(np.array(obs2))
# Out:
# episode  0
# --------
# --------
# --------
# --------
# --------
# --------
# --------
# --------
# --------
# --------
# --------
# --------
# --------
# --------
# --------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-8ce8f6677d19> in <module>()
#      53         obs2, reward, done, info = env.step(env.action_space.sample())
#      54         env.render()
# ---> 55         visualizeFrames(np.array(obs2))
#
# <ipython-input-8-8ce8f6677d19> in visualizeFrames(obs)
#      38     for i in range(0, 4):
#      39         elem = obs[:, :, i]
# ---> 40         plt.imshow(np.array(np.squeeze(elem)))
#      41         plt.show()
#      42     print('--------')
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3083            filternorm=1, filterrad=4.0, imlim=None, resample=None, url=None,
#    3084            hold=None, data=None, **kwargs):
# -> 3085     ax = gca()
#    3086     # Deprecated: allow callers to override the hold state
#    3087     # by passing hold=True|False
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/pyplot.py in gca(**kwargs)
#     960     matplotlib.figure.Figure.gca : The figure's gca method.
#     961     """
# --> 962     return gcf().gca(**kwargs)
#     963
#     964 # More ways of creating axes:
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/figure.py in gca(self, **kwargs)
#    1624
#    1625         # no axes found, so create one which spans the figure
# -> 1626         return self.add_subplot(1, 1, 1, **kwargs)
#    1627
#    1628     def sca(self, a):
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1072                     self._axstack.remove(ax)
#    1073
# -> 1074             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1075
#    1076         self._axstack.add(key, a)
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, axisbg, **kwargs)
#     539
#     540         self._connected = {}  # a dict from events to (id, func)
# --> 541         self.cla()
#     542         # funcs used to format x and y - fall back on major formatters
#     543         self.fmt_xdata = None
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/axes/_base.py in cla(self)
#     980         self.yaxis.cla()
#     981         for name, spine in six.iteritems(self.spines):
# --> 982             spine.cla()
#     983
#     984         self.ignore_existing_data_limits = True
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/spines.py in cla(self)
#     181         self._position = None  # clear position
#     182         if self.axis is not None:
# --> 183             self.axis.cla()
#     184
#     185     def is_frame_like(self):
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/axis.py in cla(self)
#     771         self._set_artist_props(self.label)
#     772
# --> 773         self.reset_ticks()
#     774
#     775         self.converter = None
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/axis.py in reset_ticks(self)
#     785         del self.minorTicks[:]
#     786
# --> 787         self.majorTicks.extend([self._get_tick(major=True)])
#     788         self.minorTicks.extend([self._get_tick(major=False)])
#     789         self._lastNumMajorTicks = 1
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2095         else:
#    2096             tick_kw = self._minor_tick_kw
# -> 2097         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2098
#    2099     def _get_label(self):
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation)
#     153
#     154         self.tick1line = self._get_tick1line()
# --> 155         self.tick2line = self._get_tick2line()
#     156         self.gridline = self._get_gridline()
#     157
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/axis.py in _get_tick2line(self)
#     581                           markeredgewidth=self._width,
#     582                           zorder=self._zorder)
# --> 583         l.set_transform(self.axes.get_yaxis_transform(which='tick2'))
#     584         self._set_artist_props(l)
#     585         return l
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/axes/_base.py in get_yaxis_transform(self, which)
#     780         elif which == 'tick2':
#     781             # for cartesian projection, this is top spine
# --> 782             return self.spines['right'].get_spine_transform()
#     783         else:
#     784             raise ValueError('unknown value for which')
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/spines.py in get_spine_transform(self)
#     440     def get_spine_transform(self):
#     441         """get the spine transform"""
# --> 442         self._ensure_position_is_set()
#     443         what, how = self._spine_transform
#     444
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/spines.py in _ensure_position_is_set(self)
#     163             # default position
#     164             self._position = ('outward', 0.0)  # in points
# --> 165             self.set_position(self._position)
#     166
#     167     def register_axis(self, axis):
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/spines.py in set_position(self, position)
#     430
#     431         if self.axis is not None:
# --> 432             self.axis.reset_ticks()
#     433         self.stale = True
#     434
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/axis.py in reset_ticks(self)
#     786
#     787         self.majorTicks.extend([self._get_tick(major=True)])
# --> 788         self.minorTicks.extend([self._get_tick(major=False)])
#     789         self._lastNumMajorTicks = 1
#     790         self._lastNumMinorTicks = 1
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2095         else:
#    2096             tick_kw = self._minor_tick_kw
# -> 2097         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2098
#    2099     def _get_label(self):
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation)
#     158         self.label1 = self._get_text1()
#     159         self.label = self.label1  # legacy name
# --> 160         self.label2 = self._get_text2()
#     161
#     162         self.gridOn = gridOn
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/axis.py in _get_text2(self)
#     547         t = mtext.Text(
#     548             x=1, y=0,
# --> 549             fontproperties=font_manager.FontProperties(size=self._labelsize),
#     550             color=self._labelcolor,
#     551             verticalalignment=vert,
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/font_manager.py in __init__(self, family, style, variant, weight, stretch, size, fname, _init)
#     697         self.set_style(style)
#     698         self.set_variant(variant)
# --> 699         self.set_weight(weight)
#     700         self.set_stretch(stretch)
#     701         self.set_file(fname)
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/font_manager.py in set_weight(self, weight)
#     841         """
#     842         if weight is None:
# --> 843             weight = rcParams['font.weight']
#     844         try:
#     845             weight = int(weight)
#
# ~/anaconda3/envs/gym/lib/python3.5/site-packages/matplotlib/__init__.py in __getitem__(self, key)
#     823                 'list of valid parameters.' % (key,))
#     824
# --> 825     def __getitem__(self, key):
#     826         inverse_alt = None
#     827         if key in _deprecated_map:
#
# KeyboardInterrupt:
